# %%
a= input("please, enter numbers separated with comas")
def average(a):
    return float(sum(a)/len(a))
print average(a)
# Out:
# please, enter numbers separated bt comas1,3,5,7,9
# 5.0

# %%
a= input("please, enter numbers separated with comas")
b= input("number of occurrencies")
def average(a):
    return float(sum(a[-b:])/b)
print average(a)
# Out:
# please, enter numbers separated bt comas1,3,5,7,9
# number of occurrencies2
# 8.0

# %%
import random
x=random.randint(1,100)
def function(x):
    if x>50:
        return "win"
    elif x==100:
        return "draw"
    else:
        return "lose"
print function(x)
print x
# Out:
# win
# 60

# %%
import pandas_datareader.data as pan
my_stocks=['AAPL', "MSFT", "TSLA"]
for i in my_stocks:
    x=pan.DataReader(i,"google")
print x.head(7)
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2010-06-29  19.00  25.00  17.54  23.89  18783276
# 2010-06-30  25.79  30.42  23.30  23.83  17194394
# 2010-07-01  25.00  25.92  20.27  21.96   8229863
# 2010-07-02  23.00  23.10  18.71  19.20   5141807
# 2010-07-06  20.00  20.00  15.83  16.11   6879296
# 2010-07-07  16.40  16.63  14.98  15.80   6924914
# 2010-07-08  16.14  17.52  15.57  17.46   7719539

# %%
import pandas_datareader.data as pan
import  matplotlib.pyplot as plt
my_stocks=['AAPL', "MSFT", "TSLA"]
for i in my_stocks:
    x=plt.plot(pan.DataReader(i,"google")["Close"])
print plt.show()
# Out:
# None

# %%
import pandas_datareader.data as pan
import  matplotlib.pyplot as plt
my_stocks=['AAPL', "MSFT", "TSLA"]
for i in my_stocks:
    x=plt.plot(pan.DataReader(i,"google")["Close"])
    print plt.show()
# Out:
# None
# None
# None
